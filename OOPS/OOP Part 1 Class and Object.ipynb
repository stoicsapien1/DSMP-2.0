# %% [markdown]
# ## Let's start learning OOPs.

# %%
L = [1,2,3]
L.upper()īīīī
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 L = [1,2,3]
# ----> 2 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
s= "hello"
s.append("x")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 s= "hello"
# ----> 2 s.append("x")
#
# AttributeError: 'str' object has no attribute 'append'

# %%
# In python everything is object

# %% [markdown]
# # Class

# %%
L = [1,2,3]
print(type(L))
# Out:
# <class 'list'>

# %%
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %% [markdown]
# #### List is a class and L is a object.
# Class is a blueprint which tells us how a object will behave

# %%
print("hello world")
# Out:
# hello world

# %%
print("4most")
# Out:
# 4most
