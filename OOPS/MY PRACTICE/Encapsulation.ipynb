# %%
class Computer:

    def __init__(self):
        self.__maxprice = 900

    def sell(self):

        print("Selling Price: {}".format(self.__maxprice))

    def setMaxPrice(self,price):
        self.__maxprice=price

# %%
comp1 = Computer()

# %%
comp1.sell()
# Out:
# Selling Price: 900

# %%
comp1.setMaxPrice(1001)

# %%
comp1.sell()
# Out:
# Selling Price: 900
